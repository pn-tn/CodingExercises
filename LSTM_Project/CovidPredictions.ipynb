        "Mar 27, 2022","Mar 28, 2022","Mar 29, 2022","Mar 30, 2022","Mar 31, 2022","Apr 01, 2022","Apr 02, 2022","Apr 03, 2022","Apr 04, 2022","Apr 05, 2022",
        "Apr 06, 2022","Apr 07, 2022","Apr 08, 2022","Apr 09, 2022","Apr 10, 2022","Apr 11, 2022","Apr 12, 2022","Apr 13, 2022","Apr 14, 2022","Apr 15, 2022",
        "Apr 16, 2022","Apr 17, 2022","Apr 18, 2022","Apr 19, 2022","Apr 20, 2022","Apr 21, 2022","Apr 22, 2022","Apr 23, 2022","Apr 24, 2022","Apr 25, 2022",
        "Apr 26, 2022","Apr 27, 2022","Apr 28, 2022","Apr 29, 2022","Apr 30, 2022","May 01, 2022","May 02, 2022","May 03, 2022","May 04, 2022","May 05, 2022",
        "May 06, 2022","May 07, 2022","May 08, 2022","May 09, 2022","May 10, 2022","May 11, 2022","May 12, 2022","May 13, 2022","May 14, 2022","May 15, 2022",
        "May 16, 2022","May 17, 2022","May 18, 2022","May 19, 2022","May 20, 2022","May 21, 2022","May 22, 2022","May 23, 2022","May 24, 2022","May 25, 2022",
        "May 26, 2022","May 27, 2022","May 28, 2022","May 29, 2022","May 30, 2022","May 31, 2022","Jun 01, 2022","Jun 02, 2022","Jun 03, 2022","Jun 04, 2022",
        "Jun 05, 2022","Jun 06, 2022","Jun 07, 2022","Jun 08, 2022","Jun 09, 2022","Jun 10, 2022","Jun 11, 2022","Jun 12, 2022","Jun 13, 2022","Jun 14, 2022",
        "Jun 15, 2022","Jun 16, 2022","Jun 17, 2022","Jun 18, 2022","Jun 19, 2022","Jun 20, 2022","Jun 21, 2022","Jun 22, 2022","Jun 23, 2022","Jun 24, 2022",
        "Jun 25, 2022","Jun 26, 2022","Jun 27, 2022","Jun 28, 2022","Jun 29, 2022","Jun 30, 2022","Jul 01, 2022","Jul 02, 2022","Jul 03, 2022","Jul 04, 2022",
        "Jul 05, 2022","Jul 06, 2022","Jul 07, 2022","Jul 08, 2022","Jul 09, 2022","Jul 10, 2022","Jul 11, 2022","Jul 12, 2022","Jul 13, 2022","Jul 14, 2022",
        "Jul 15, 2022","Jul 16, 2022","Jul 17, 2022","Jul 18, 2022","Jul 19, 2022","Jul 20, 2022","Jul 21, 2022","Jul 22, 2022","Jul 23, 2022","Jul 24, 2022"]

data = {'Day': days,
       'Cases': cases}

df = pd.DataFrame(data)

print(df.shape)

df
# Out:
# (890, 2)
#               Day  Cases
# 0    Feb 16, 2020      0
# 1    Feb 17, 2020      0
# 2    Feb 18, 2020      0
# 3    Feb 19, 2020      0
# 4    Feb 20, 2020      0
# ..            ...    ...
# 885  Jul 20, 2022   2073
# 886  Jul 21, 2022   2827
# 887  Jul 22, 2022   3389
# 888  Jul 23, 2022   3502
# 889  Jul 24, 2022   3748
#
# [890 rows x 2 columns]

# %%
# what the data looks like

plt.figure(figsize=(15, 6))
plt.plot(df['Cases'], label = 'cases')
plt.ylabel('number o cases')
plt.title('Daily Covid Cases')
plt.legend()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

df.sort_index(inplace=True)
p = 50
results = seasonal_decompose(df['Cases'], period = p)

fig = results.plot();
fig.set_size_inches((20, 7))

# %%
# data splitting:
#  60% - train
#  20% - test
#  20% - validation

# train and testing set will be gathered from first and last parts of the data

c = len(cases)
tr_len = 0.6 * c
tr_len = int(tr_len)
_len = 0.2 * c
_len = int(_len)

print(tr_len)
print(_len)

validation_array = df['Cases'][0 : _len]
validation_array = np.resize(validation_array, (validation_array.shape[0],1))

training_array = df['Cases'][_len : tr_len+_len]
training_array = np.resize(training_array, (training_array.shape[0],1))

te = tr_len + _len
testing_array = df['Cases'][tr_len+_len : c]
testing_array = np.resize(testing_array, (testing_array.shape[0],1))

print(validation_array.shape)
print(training_array.shape)
print(testing_array.shape)
# Out:
# 534
# 178
# (178, 1)
# (534, 1)
# (178, 1)

# %%
# What the split looks like

# validation set
plt.plot(validation_array, label = 'val', color = 'plum')

plt.ylabel('number o cases')
plt.title('first 20% of days')
plt.legend()

# %%
# traninig set
plt.figure(figsize=(15, 6))

plt.plot(training_array, label = 'tr', color = 'dodgerblue')

plt.ylabel('number o cases')
plt.title('Cases')
plt.legend()

# %%
# testing set
plt.plot(testing_array, label = 'val', color = 'salmon')

plt.ylabel('number o cases')
plt.title('last 20% of days')
plt.legend()

# %%
# scaling the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()


scaler = scaler.fit(training_array)
df_tr_ = scaler.transform(training_array)
scaled_training_array = df_tr_
#print(training_array)

scaler = scaler.fit(testing_array)
df_te_ = scaler.transform(testing_array)
scaled_testing_array = df_te_
#print(testing_array)

scaler = scaler.fit(validation_array)
df_va_ = scaler.transform(validation_array)
scaled_validation_array = df_va_
#print(validation_array)

# %%
# split into a sequence
from numpy import array

def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps
        
        if end_ix > len(sequence)-1:
            break
            
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
# define the n_steps and n_features

n_steps = 5
n_features = 1

# %%
# split the data at n_steps

X_tr, y_tr = split_sequence(training_array,n_steps)
X_te, y_te = split_sequence(testing_array,n_steps)
X_va, y_va = split_sequence(validation_array,n_steps)

# scaled version of the split
X_tr_s, y_tr_s = split_sequence(scaled_training_array,n_steps)
X_te_s, y_te_s = split_sequence(scaled_testing_array,n_steps)
X_va_s, y_va_s = split_sequence(scaled_validation_array,n_steps)

print(X_tr.shape)
print(y_tr.shape)

print(X_te.shape)
print(y_te.shape)

print(X_va.shape)
print(y_va.shape)

# first index ra akong e print
print(":D \n", X_tr[0], "--->", y_tr[0])
# Out:
# (529, 5, 1)
# (529, 1)
# (173, 5, 1)
# (173, 1)
# (173, 5, 1)
# (173, 1)
# :D
#  [[4219]
#  [3920]
#  [6123]
#  [4266]
#  [3327]] ---> [3217]

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Bidirectional

model = Sequential()
model.add(Bidirectional((LSTM(50, return_sequences = True, activation='relu')), input_shape=(n_steps, n_features)))
model.add(Bidirectional((LSTM(50)), input_shape=(n_steps, n_features)))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
model.fit(X_tr_s, y_tr_s, epochs=60, verbose=0)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  bidirectional (Bidirectiona  (None, 5, 100)           20800
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 100)              60400
#  nal)
#
#  dense (Dense)               (None, 1)                 101
#
# ...
# Total params: 81,301
# Trainable params: 81,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from math import sqrt

def forecast_lstm(model_, batch_size, X_input):
    X_input = X_input.reshape((batch_size, n_steps, n_features))
    #print(X_input)
    yhat = model_.predict(X_input, verbose=0)
    #print(yhat.shape)
    return yhat[0,0]

# @param:
#   model <-- the model 
#   Xval, yval  <-- the validation set
def evaluate_lstm_model(model_, Xval, yval):
    predictions = list()
    for i in range(len(Xval)):
        yhat = forecast_lstm(model_, 1, Xval[i])
        predictions.append(yhat)
        
    # calculate out of sample error
    mse = mean_squared_error(yval, predictions)
    rmse = sqrt(mse)
    print(rmse)
    
    # I cannot dataframe the df_10 because it needs to be a 1d array
    # so i change y_va to 1d
    print(yval.shape)
    Aaa = yval.reshape(yval.shape[0])
    print(yval.shape)
    
    df_10 = {'Expected':Aaa, 'predictions':predictions}
    df_10 = pd.DataFrame(df_10)
    #print(df_10)
    return rmse, df_10["predictions"]

# %%
rmse, pred = evaluate_lstm_model(model, X_va_s, y_va_s)

# undo the scaling 
print(pred.shape)
pred= np.resize(pred, (pred.shape[0],1))
pred_val = scaler.inverse_transform(pred)

print(rmse)
# Out:
# 0.5643825651619194
# (173, 1)
# (173, 1)
# (173,)
# 0.5643825651619194

# %%
fig = plt.figure(figsize=(15,6))
plt.plot(y_va, label = 'validation data')
plt.plot(pred_val, label = 'predicted data')
plt.legend()

# %%
rmse, pred = evaluate_lstm_model(model, X_te_s, y_te_s)

# undo the scaling 
print(pred.shape)
pred= np.resize(pred, (pred.shape[0],1))
pred_tes = scaler.inverse_transform(pred)

print(rmse)
# Out:
# 0.21794131683605414
# (173, 1)
# (173, 1)
# (173,)
# 0.21794131683605414

# %%
fig = plt.figure(figsize=(15,6))
plt.plot(y_te, label = 'test data')
plt.plot(pred_tes, label = 'predicted data')
plt.legend()

# %%
# now that parameters and everything else are to my likng,
# I'll be using the entire data as a training set to predict
# future data using the same model

# %%
print(len(cases))

# reshape original data to a new data
new_data = np.resize(cases, (len(cases), 1))

print(new_data.shape)
# Out:
# 890
# (890, 1)

# %%
# scaling
scaler = scaler.fit(new_data)
df_nd = scaler.transform(new_data)
scaled_new_data = df_nd

# %%
n_steps = 5
n_features = 1

# split data
X_data, y_data = split_sequence(new_data,n_steps)

# scaled version of the split
X_data_s, y_data_s = split_sequence(scaled_new_data,n_steps)

# %%
# fit scaled version of split 
model_1 = model
model_1.fit(X_data_s, y_data_s, epochs=60, verbose=0)
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  bidirectional (Bidirectiona  (None, 5, 100)           20800
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 100)              60400
#  nal)
#
#  dense (Dense)               (None, 1)                 101
#
# ...
# Total params: 81,301
# Trainable params: 81,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
rmse, pred = evaluate_lstm_model(model_1, X_data_s, y_data_s)

print(X_data_s.shape)

# undo the scaling 
print(pred.shape)
pred= np.resize(pred, (pred.shape[0],1))
pred_new = scaler.inverse_transform(pred)

print(rmse)

fig = plt.figure(figsize=(15,6))
plt.plot(y_data, label = 'data')
plt.plot(pred_new, label = 'predicted data')
# Out:
# 0.18894371891009498
# (885, 1)
# (885, 1)
# (885, 5, 1)
# (885,)
# 0.18894371891009498

# %%
Dta = np.array([])
Dta = np.append(Dta, scaled_new_data)

print(Dta.shape)

# @param
#   rec = number of times recursion occurs

def pred_(model, data, n_step, rec):
    global Dta
    # get the last set in the data
    l = data.shape[0]
    X = data[l-n_step:l] 
    
    y = forecast_lstm(model, 1, X)
    
    #print(X, y)
    data = np.append(data, y)
    
    if rec <= 0:
        return data
    else:
        rec = rec-1
        data = pred_(model, data, n_step, rec)
    
    return data
# Out:
# (890,)

# %%
a = pred_(model_1, Dta, n_steps, 100)

# %%
plt.figure(figsize=(10,6))
plt.plot(a)
plt.title('The model after adding 100 days')
# Out:
# Text(0.5, 1.0, 'The model after adding 100 days')

# %%
plt.figure(figsize=(10,6))

ind = array([])
for i in range(190):
    ind = np.append(ind, i)
l = a[800:890]
r = a[889:990]

# undothe scaling
l= np.resize(l, (l.shape[0],1))
l = scaler.inverse_transform(l)

r= np.resize(r, (r.shape[0],1))
r = scaler.inverse_transform(r)

plt.plot(ind[:90], l, label = 'data')
plt.plot(ind[89:], r, label = 'prediction')
plt.legend()
plt.title('closer look')
# Out:
# Text(0.5, 1.0, 'closer look')

# %%
## from here, codes will be for connecting it to anvil

# %%
import anvil.server

anvil.server.connect("ZQ27HGCMEJOUDHLGANJUSDS4-KN23PICHI5RBPE6X")
# Out:
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default environment" as SERVER

# %%
import anvil.media
import anvil.mpl_util

@anvil.server.callable
def show_data():
    plt.figure(figsize=(15, 6))
    plt.plot(df['Cases'], label = 'cases')
    plt.ylabel('number o cases')
    plt.title('Daily Covid Cases')
    plt.legend()
    return anvil.mpl_util.plot_image()

@anvil.server.callable
def val_pred():

    fig = plt.figure(figsize=(15,6))
    plt.plot(y_va, label = 'validation data')
    plt.plot(pred_val, label = 'predicted data')
    plt.ylabel('number o cases')
    plt.title('validation set')
    plt.legend()
    return anvil.mpl_util.plot_image()

@anvil.server.callable
def tes_pred():

    fig = plt.figure(figsize=(15,6))
    plt.plot(y_te, label = 'test data')
    plt.plot(pred_tes, label = 'predicted data')
    plt.ylabel('number o cases')
    plt.title('testing set')
    plt.legend()
    return anvil.mpl_util.plot_image()
    
@anvil.server.callable
def new_pred():
    fig = plt.figure(figsize=(15,6))
    plt.plot(ind[:90], l, label = 'data')
    plt.plot(ind[89:], r, label = 'prediction')
    plt.ylabel('number o cases')
    plt.legend()
    plt.title('predictions for next 100 days')
    return anvil.mpl_util.plot_image()
